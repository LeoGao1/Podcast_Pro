# %%
import logging
import boto3
from botocore.exceptions import ClientError
import os

# %%
#define variables

course_name = 'dsc40a'
audios_path = './'+course_name+'_audio'

# %%
def bucket_exists(bucket_name):
    """Determine whether bucket_name exists and the user has permission to access it

    :param bucket_name: string
    :return: True if the referenced bucket_name exists, otherwise False
    """

    s3 = boto3.client('s3')
    try:
        response = s3.head_bucket(Bucket=bucket_name)
    except ClientError as e:
        logging.debug(e)
        return False
    return True

# %%
def create_bucket(bucket_name, region=None):
    """Create an S3 bucket in a specified region

    If a region is not specified, the bucket is created in the S3 default
    region (us-east-1).

    :param bucket_name: Bucket to create
    :param region: String region to create bucket in, e.g., 'us-west-2'
    :return: True if bucket created, else False
    """

    # Create bucket
    try:
        if region is None:
            s3_client = boto3.client('s3')
            s3_client.create_bucket(Bucket=bucket_name)
        else:
            s3_client = boto3.client('s3', region_name=region)
            location = {'LocationConstraint': region}
            s3_client.create_bucket(Bucket=bucket_name,
                                    CreateBucketConfiguration=location)
    except ClientError as e:
        logging.error(e)
        return False
    return True

# %%
bucket_name = 'podcastpro--'+ course_name

#record exist bucket name
exist_name= ['leo-test11','podcastpro--dsc40a']

# %%
#create new bucket for this course

#default region
region = 'us-west-2'

# Set up logging
logging.basicConfig(level=logging.DEBUG,
                    format='%(levelname)s: %(asctime)s: %(message)s')

# Create a bucket in a specified region
if create_bucket(bucket_name, region):
    logging.info(f'Created bucket {bucket_name} '
                 f'in region {region}')
# Out:
# DEBUG: 2019-11-19 19:26:44,750: Event choose-service-name: calling handler <function handle_service_name_alias at 0x110536950>
# DEBUG: 2019-11-19 19:26:44,754: Event creating-client-class.s3: calling handler <function add_generate_presigned_post at 0x1105203b0>
# DEBUG: 2019-11-19 19:26:44,755: Event creating-client-class.s3: calling handler <function lazy_call.<locals>._handler at 0x1105c4320>
# DEBUG: 2019-11-19 19:26:44,756: Event creating-client-class.s3: calling handler <function add_generate_presigned_url at 0x110520170>
# DEBUG: 2019-11-19 19:26:44,756: The s3 config key is not a dictionary type, ignoring its value of: None
# DEBUG: 2019-11-19 19:26:44,782: Setting s3 timeout as (60, 60)
# DEBUG: 2019-11-19 19:26:44,784: Registering retry handlers for service: s3
# DEBUG: 2019-11-19 19:26:44,786: Defaulting to S3 virtual host style addressing with path style addressing fallback.
# ...

# %%
# upload new files, need to wait for response

# Create an S3 client
S3 = boto3.client('s3')

for root,dirs,files in os.walk(audios_path):
    for file in files:
        S3.upload_file(os.path.join(root,file),bucket_name,file)
# Out:
# DEBUG: 2019-11-19 19:27:12,725: Event choose-service-name: calling handler <function handle_service_name_alias at 0x110536950>
# DEBUG: 2019-11-19 19:27:12,729: Event creating-client-class.s3: calling handler <function add_generate_presigned_post at 0x1105203b0>
# DEBUG: 2019-11-19 19:27:12,730: Event creating-client-class.s3: calling handler <function lazy_call.<locals>._handler at 0x1105c4320>
# DEBUG: 2019-11-19 19:27:12,731: Event creating-client-class.s3: calling handler <function add_generate_presigned_url at 0x110520170>
# DEBUG: 2019-11-19 19:27:12,732: The s3 config key is not a dictionary type, ignoring its value of: None
# DEBUG: 2019-11-19 19:27:12,779: Setting s3 timeout as (60, 60)
# DEBUG: 2019-11-19 19:27:12,781: Registering retry handlers for service: s3
# DEBUG: 2019-11-19 19:27:12,783: Defaulting to S3 virtual host style addressing with path style addressing fallback.
# DEBUG: 2019-11-19 19:27:12,787: Acquiring 0
# ...
